# %%
# %load_ext autoreload
# %autoreload

# %%
import gzip
from Bio import SeqIO

# %%
# %%time

gbrec = list(SeqIO.parse('../data/GCF_000005845.2_ASM584v2_genomic.gbff', 'genbank'))[0]
# Out:
# CPU times: user 1.14 s, sys: 79.5 ms, total: 1.21 s
# Wall time: 1.27 s

# %%
gene_features = [f for f in gbrec.features if f.type == 'gene']

# %%
# %%time

len(gbrec.seq)
# Out:
# CPU times: user 13 µs, sys: 1 µs, total: 14 µs
# Wall time: 19.1 µs
# 4641652

# %%
def tileset_info(gbrec):
    ret_val = {
          'tile_size': 1024,
          'max_zoom': 22,
          'max_width': len(gbrec.seq),
          'min_pos': [0],
          'max_pos': [len(gbrec.seq)]
    }
    return ret_val;

tsinfo = tileset_info(gbrec)
print(tsinfo)
# Out:
# {'tile_size': 1024, 'max_zoom': 22, 'max_width': 4641652, 'min_pos': [0], 'max_pos': [4641652]}

# %%
import slugid

def filler_to_genepred(filler, strand):
    return {
        'xStart': filler['start'],
        'xEnd': filler['end'],
        'type': 'filler',
        'uid': slugid.nice(),
        'fields': [],
        'strand': strand,
    }

def gb_to_genepred(gb):
    importance = gb.location.end - gb.location.start;
    strand = '+' if gb.strand == 1 else '-'
    uid = slugid.nice();
    
    if gb.type == 'filler':
      # this is annotation that was generated by collapsing genes and is
      # only meant to show that there is something there.
        return {
            'xStart': gb.location.start,
            'xEnd': gb.location.end,
            'strand': gb.strand,
            'fields': [],
            'type': 'filler',
            'uid': uid,
        }
      
    name = gb.qualifiers['gene'][0]
    start = int(gb.location.start)
    end = int(gb.location.end)
    
    return {
      'xStart': int(gb.location.start),
      'xEnd': int(gb.location.end),
      'strand': strand,
      'chrOffset': 0,
      'importance': gb.location.end - gb.location.start,
      'uid': uid,
      'fields': [
        'chrom', start, end,
          name, importance, strand, '', '', gb.type,
          name, str(start), str(end),
          str(start), str(end)
      ]
    }

gb_to_genepred(gene_features[0])
# Out:
# {'xStart': 189,
#  'xEnd': 255,
#  'strand': '+',
#  'chrOffset': 0,
#  'importance': 66,
#  'uid': 'G7HKm0gqSZyTk5ucfReqmw',
#  'fields': ['chrom',
#   189,
#   255,
#   'thrL',
#   66,
#   '+',
#   '',
#   'gene',
#   'thrL',
#   '189',
#   '255',
#   '189',
#   '255']}

# %%
"""
* Take a list of genes, which can be any list with elements containing
* { start, end } fields and return another list of { start, end } 
* fields containing the collapsed genes. 
*
* The segments should be sorted by their start coordinate.
*
* The scale parameter is the number of base pairs per pixels
"""
def collapse(segments, scale):
    collapsed = []

    # the maximum distance we allow between segments before collapsing them
    MAX_DIST_BETWEEN = 5

    # no segments in, no segments out
    if not len(segments):
      return []

    #start with the first segment
    curr_start = segments[0].location.start;
    curr_end = segments[0].location.end;

    # continue on to the next segments
    for segment in segments:
        if segment.location.start < curr_end + MAX_DIST_BETWEEN * 1 / scale:
            curr_end = max(curr_end, segment.location.end)
        else:
            collapsed += [{
                'type': 'filler',
                'start': curr_start,
                'end': curr_end,
            }]
            
            curr_start = segment.location.start
            curr_end = segment.location.end

    # add the final segment
    collapsed += [{
        'start': curr_start,
        'end': curr_end,
        'type': 'filler',
    }]

#     print('collapsed:', collapsed)
    return collapsed

# %%
tiles(gbrec, tsinfo, 0, 0)
# Out:
# [{'xStart': 189,
#   'xEnd': 255,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 66,
#   'uid': 'XGVsdT-4SnS5dqPOnP1U8g',
#   'fields': ['chrom',
#    189,
#    255,
#    'thrL',
#    66,
#    '+',
#    '',
#    'gene',
#    'thrL',
#    '189',
#    '255',
#    '189',
#    '255']},
#  {'xStart': 336,
#   'xEnd': 2799,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 2463,
#   'uid': 'RBUyFTetQ66ZOUs1ab3IHw',
#   'fields': ['chrom',
#    336,
#    2799,
#    'thrA',
#    2463,
#    '+',
#    '',
#    'gene',
#    'thrA',
#    '336',
#    '2799',
#    '336',
#    '2799']},
#  {'xStart': 2800,
#   'xEnd': 3733,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 933,
#   'uid': 'cLMNdv4zRCy8jNhfUqbMSQ',
#   'fields': ['chrom',
#    2800,
#    3733,
#    'thrB',
#    933,
#    '+',
#    '',
#    'gene',
#    'thrB',
#    '2800',
#    '3733',
#    '2800',
#    '3733']},
#  {'xStart': 3733,
#   'xEnd': 5020,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 1287,
#   'uid': 'dSEV5R_NRBS1q8CN-sPW_w',
#   'fields': ['chrom',
#    3733,
#    5020,
#    'thrC',
#    1287,
#    '+',
#    '',
#    'gene',
#    'thrC',
#    '3733',
#    '5020',
#    '3733',
#    '5020']},
#  {'xStart': 5233,
#   'xEnd': 5530,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 297,
#   'uid': 'AYRSVb4uQYSNWU6i23AsOg',
#   'fields': ['chrom',
#    5233,
#    5530,
#    'yaaX',
#    297,
#    '+',
#    '',
#    'gene',
#    'yaaX',
#    '5233',
#    '5530',
#    '5233',
#    '5530']},
#  {'xStart': 5682,
#   'xEnd': 6459,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 777,
#   'uid': 'Ojy1xp25SOe7zBM5Wla9LA',
#   'fields': ['chrom',
#    5682,
#    6459,
#    'yaaA',
#    777,
#    '-',
#    '',
#    'gene',
#    'yaaA',
#    '5682',
#    '6459',
#    '5682',
#    '6459']},
#  {'xStart': 6528,
#   'xEnd': 7959,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 1431,
#   'uid': 'LsSCE4bDTbGjG7u0yaLZPg',
#   'fields': ['chrom',
#    6528,
#    7959,
#    'yaaJ',
#    1431,
#    '-',
#    '',
#    'gene',
#    'yaaJ',
#    '6528',
#    '7959',
#    '6528',
#    '7959']},
#  {'xStart': 8237,
#   'xEnd': 9191,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 954,
#   'uid': 'J3VaDX5wRzK2Dwg3S2EIPw',
#   'fields': ['chrom',
#    8237,
#    9191,
#    'talB',
#    954,
#    '+',
#    '',
#    'gene',
#    'talB',
#    '8237',
#    '9191',
#    '8237',
#    '9191']},
#  {'xStart': 9305,
#   'xEnd': 9893,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 588,
#   'uid': 'XFpD53myQnW5rwxP4GJbhQ',
#   'fields': ['chrom',
#    9305,
#    9893,
#    'mog',
#    588,
#    '+',
#    '',
#    'gene',
#    'mog',
#    '9305',
#    '9893',
#    '9305',
#    '9893']},
#  {'xStart': 9927,
#   'xEnd': 10494,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 567,
#   'uid': 'Zcg0r1MQSweJ2igjLNDpFQ',
#   'fields': ['chrom',
#    9927,
#    10494,
#    'satP',
#    567,
#    '-',
#    '',
#    'gene',
#    'satP',
#    '9927',
#    '10494',
#    '9927',
#    '10494']},
#  {'xStart': 10642,
#   'xEnd': 11356,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 714,
#   'uid': 'M_RG03hkQGOmarm3n-3dCA',
#   'fields': ['chrom',
#    10642,
#    11356,
#    'yaaW',
#    714,
#    '-',
#    '',
#    'gene',
#    'yaaW',
#    '10642',
#    '11356',
#    '10642',
#    '11356']},
#  {'xStart': 10829,
#   'xEnd': 11315,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 486,
#   'uid': 'X__nPILGRpewatbd9Kx8dg',
#   'fields': ['chrom',
#    10829,
#    11315,
#    'mbiA',
#    486,
#    '+',
#    '',
#    'gene',
#    'mbiA',
#    '10829',
#    '11315',
#    '10829',
#    '11315']},
#  {'xStart': 11381,
#   'xEnd': 11786,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 405,
#   'uid': 'Jj9g5XsDS2-4rHBiA9Rhew',
#   'fields': ['chrom',
#    11381,
#    11786,
#    'yaaI',
#    405,
#    '-',
#    '',
#    'gene',
#    'yaaI',
#    '11381',
#    '11786',
#    '11381',
#    '11786']},
#  {'xStart': 12162,
#   'xEnd': 14079,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 1917,
#   'uid': 'EvNJN71VR9mzKpFV8Vqs7g',
#   'fields': ['chrom',
#    12162,
#    14079,
#    'dnaK',
#    1917,
#    '+',
#    '',
#    'gene',
#    'dnaK',
#    '12162',
#    '14079',
#    '12162',
#    '14079']},
#  {'xStart': 14167,
#   'xEnd': 15298,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 1131,
#   'uid': 'F3mqRioCQbWSK0k-6v4GVA',
#   'fields': ['chrom',
#    14167,
#    15298,
#    'dnaJ',
#    1131,
#    '+',
#    '',
#    'gene',
#    'dnaJ',
#    '14167',
#    '15298',
#    '14167',
#    '15298']},
#  {'xStart': 15444,
#   'xEnd': 16557,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 1113,
#   'uid': 'Qnl2HBzjTcyOlYAi9-55gQ',
#   'fields': ['chrom',
#    15444,
#    16557,
#    'insL-1',
#    1113,
#    '+',
#    '',
#    'gene',
#    'insL-1',
#    '15444',
#    '16557',
#    '15444',
#    '16557']},
#  {'xStart': 16750,
#   'xEnd': 16960,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 210,
#   'uid': 'aS6rGMnbQU2xhagaLExugA',
#   'fields': ['chrom',
#    16750,
#    16960,
#    'mokC',
#    210,
#    '-',
#    '',
#    'gene',
#    'mokC',
#    '16750',
#    '16960',
#    '16750',
#    '16960']},
#  {'xStart': 16750,
#   'xEnd': 16903,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 153,
#   'uid': 'HWTGDWIrSnmv4lWfm7uMug',
#   'fields': ['chrom',
#    16750,
#    16903,
#    'hokC',
#    153,
#    '-',
#    '',
#    'gene',
#    'hokC',
#    '16750',
#    '16903',
#    '16750',
#    '16903']},
#  {'xStart': 16951,
#   'xEnd': 17006,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 55,
#   'uid': 'PrxnzlOzR3OKP62r-t6BIQ',
#   'fields': ['chrom',
#    16951,
#    17006,
#    'sokC',
#    55,
#    '+',
#    '',
#    'gene',
#    'sokC',
#    '16951',
#    '17006',
#    '16951',
#    '17006']},
#  {'xStart': 17488,
#   'xEnd': 18655,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 1167,
#   'uid': 'PLNrD8ZYTbmvVUkrM1OmGw',
#   'fields': ['chrom',
#    17488,
#    18655,
#    'nhaA',
#    1167,
#    '+',
#    '',
#    'gene',
#    'nhaA',
#    '17488',
#    '18655',
#    '17488',
#    '18655']},
#  {'xStart': ExactPosition(189),
#   'xEnd': ExactPosition(1557056),
#   'type': 'filler',
#   'uid': 'ZzLEEdbcQ2uYA-v6d-XSjA',
#   'fields': [],
#   'strand': '+'},
#  {'xStart': ExactPosition(1579544),
#   'xEnd': ExactPosition(1579667),
#   'type': 'filler',
#   'uid': 'ALH_bu_ET0WaOQTB_biLfA',
#   'fields': [],
#   'strand': '+'},
#  {'xStart': ExactPosition(1601489),
#   'xEnd': ExactPosition(2097225),
#   'type': 'filler',
#   'uid': 'eRvwR7RsTfa_71tKGtcGyA',
#   'fields': [],
#   'strand': '+'},
#  {'xStart': ExactPosition(2137901),
#   'xEnd': ExactPosition(3898609),
#   'type': 'filler',
#   'uid': 'Ef-8lY4JT9SXp0QJnMxaig',
#   'fields': [],
#   'strand': '+'},
#  {'xStart': ExactPosition(3927154),
#   'xEnd': ExactPosition(4641628),
#   'type': 'filler',
#   'uid': 'Zs5K6UKsSJ6oF9znf9Z-ww',
#   'fields': [],
#   'strand': '+'},
#  {'xStart': ExactPosition(5682),
#   'xEnd': ExactPosition(85511),
#   'type': 'filler',
#   'uid': 'XDkxDUbEQOyQVApbCiI16g',
#   'fields': [],
#   'strand': '-'},
#  {'xStart': ExactPosition(111648),
#   'xEnd': ExactPosition(189506),
#   'type': 'filler',
#   'uid': 'ZUwGh047Q1yS90oJN8h0Yg',
#   'fields': [],
#   'strand': '-'},
#  {'xStart': ExactPosition(213677),
#   'xEnd': ExactPosition(4394067),
#   'type': 'filler',
#   'uid': 'RtzfGDryQ7KlNzPeu_VeJQ',
#   'fields': [],
#   'strand': '-'},
#  {'xStart': ExactPosition(4416016),
#   'xEnd': ExactPosition(4640306),
#   'type': 'filler',
#   'uid': 'N_gnPoh_RlKzt_8OV5TofA',
#   'fields': [],
#   'strand': '-'}]

# %%
def tiles(gbrec, tsinfo, z, x):
    tile_width = tsinfo['max_width'] / 2 ** z;
    

    # get the bounds of the tile
    min_x = tsinfo['min_pos'][0] + x * tile_width;
    max_x = tsinfo['min_pos'][0] + (x + 1) * tile_width;

    gene_features = [f for f in gbrec.features if f.type == 'gene']
    
    filtered = list(filter(
        lambda x: x.type == 'gene' and x.location.end > min_x and x.location.start < max_x,
        gene_features))
    scale_factor = 1024 / (2 ** (tsinfo['max_zoom'] - z));
    
    collapsed_plus = [{**c, **{'strand': '+'}} for c in
        collapse(list(filter(lambda x: x.strand == 1, filtered)), scale_factor)]
    collapsed_minus = [{**c, **{'strand': '-'}} for c in
        collapse(list(filter(lambda x: x.strand != 1, filtered)), scale_factor)]

    values = []
    tile_capacity = 20
    
    for feature in gene_features:
        if len(values) >= tile_capacity:
            break
        
        if feature.location.end >= min_x and feature.location.start <= max_x:
            values += [gb_to_genepred(feature)]
    
    values = (values + 
              [filler_to_genepred(c, '+') for c in collapsed_plus] + 
              [filler_to_genepred(c, '-') for c in collapsed_minus])

    return values # .map(x => gbToHgGene(x));

# %%
tiles(gbrec, tsinfo, 0, 0)
# Out:
# [{'xStart': 189,
#   'xEnd': 255,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 66,
#   'uid': 'Tb_w2j9TQXiA7ZBbIALqUQ',
#   'fields': ['chrom',
#    189,
#    255,
#    'thrL',
#    66,
#    '+',
#    '',
#    'gene',
#    'thrL',
#    '189',
#    '255',
#    '189',
#    '255']},
#  {'xStart': 336,
#   'xEnd': 2799,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 2463,
#   'uid': 'YKMUot85SQeowv90JTfflg',
#   'fields': ['chrom',
#    336,
#    2799,
#    'thrA',
#    2463,
#    '+',
#    '',
#    'gene',
#    'thrA',
#    '336',
#    '2799',
#    '336',
#    '2799']},
#  {'xStart': 2800,
#   'xEnd': 3733,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 933,
#   'uid': 'DLE11LAdT0Kvb0p6Nmswkw',
#   'fields': ['chrom',
#    2800,
#    3733,
#    'thrB',
#    933,
#    '+',
#    '',
#    'gene',
#    'thrB',
#    '2800',
#    '3733',
#    '2800',
#    '3733']},
#  {'xStart': 3733,
#   'xEnd': 5020,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 1287,
#   'uid': 'fmsiWIhURLqFytHd4qAKqg',
#   'fields': ['chrom',
#    3733,
#    5020,
#    'thrC',
#    1287,
#    '+',
#    '',
#    'gene',
#    'thrC',
#    '3733',
#    '5020',
#    '3733',
#    '5020']},
#  {'xStart': 5233,
#   'xEnd': 5530,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 297,
#   'uid': 'bYxJxQMKTRCOzuKDNEKUPg',
#   'fields': ['chrom',
#    5233,
#    5530,
#    'yaaX',
#    297,
#    '+',
#    '',
#    'gene',
#    'yaaX',
#    '5233',
#    '5530',
#    '5233',
#    '5530']},
#  {'xStart': 5682,
#   'xEnd': 6459,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 777,
#   'uid': 'JSIJLdH7RDOT22wcS7sWiQ',
#   'fields': ['chrom',
#    5682,
#    6459,
#    'yaaA',
#    777,
#    '-',
#    '',
#    'gene',
#    'yaaA',
#    '5682',
#    '6459',
#    '5682',
#    '6459']},
#  {'xStart': 6528,
#   'xEnd': 7959,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 1431,
#   'uid': 'NEXuCHJmRveGOk9Lzjl0kQ',
#   'fields': ['chrom',
#    6528,
#    7959,
#    'yaaJ',
#    1431,
#    '-',
#    '',
#    'gene',
#    'yaaJ',
#    '6528',
#    '7959',
#    '6528',
#    '7959']},
#  {'xStart': 8237,
#   'xEnd': 9191,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 954,
#   'uid': 'BsVEXZYVSK-X9WE1umZ21Q',
#   'fields': ['chrom',
#    8237,
#    9191,
#    'talB',
#    954,
#    '+',
#    '',
#    'gene',
#    'talB',
#    '8237',
#    '9191',
#    '8237',
#    '9191']},
#  {'xStart': 9305,
#   'xEnd': 9893,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 588,
#   'uid': 'W8OeZ0LIRe-Z3800ED1LeA',
#   'fields': ['chrom',
#    9305,
#    9893,
#    'mog',
#    588,
#    '+',
#    '',
#    'gene',
#    'mog',
#    '9305',
#    '9893',
#    '9305',
#    '9893']},
#  {'xStart': 9927,
#   'xEnd': 10494,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 567,
#   'uid': 'B2aUi2B8QLWTiPpZpr9-wg',
#   'fields': ['chrom',
#    9927,
#    10494,
#    'satP',
#    567,
#    '-',
#    '',
#    'gene',
#    'satP',
#    '9927',
#    '10494',
#    '9927',
#    '10494']},
#  {'xStart': 10642,
#   'xEnd': 11356,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 714,
#   'uid': 'dYgqh1SCRYulA3K5QLvqBQ',
#   'fields': ['chrom',
#    10642,
#    11356,
#    'yaaW',
#    714,
#    '-',
#    '',
#    'gene',
#    'yaaW',
#    '10642',
#    '11356',
#    '10642',
#    '11356']},
#  {'xStart': 10829,
#   'xEnd': 11315,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 486,
#   'uid': 'Ja7MZKJFRjSU9RsZnzxbEw',
#   'fields': ['chrom',
#    10829,
#    11315,
#    'mbiA',
#    486,
#    '+',
#    '',
#    'gene',
#    'mbiA',
#    '10829',
#    '11315',
#    '10829',
#    '11315']},
#  {'xStart': 11381,
#   'xEnd': 11786,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 405,
#   'uid': 'RsWRSDxKT9Weq8iaY36VSA',
#   'fields': ['chrom',
#    11381,
#    11786,
#    'yaaI',
#    405,
#    '-',
#    '',
#    'gene',
#    'yaaI',
#    '11381',
#    '11786',
#    '11381',
#    '11786']},
#  {'xStart': 12162,
#   'xEnd': 14079,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 1917,
#   'uid': 'e7-W8DQvTfe59CaZW48XCQ',
#   'fields': ['chrom',
#    12162,
#    14079,
#    'dnaK',
#    1917,
#    '+',
#    '',
#    'gene',
#    'dnaK',
#    '12162',
#    '14079',
#    '12162',
#    '14079']},
#  {'xStart': 14167,
#   'xEnd': 15298,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 1131,
#   'uid': 'KW-jTb8JSWS2cOHan8LevA',
#   'fields': ['chrom',
#    14167,
#    15298,
#    'dnaJ',
#    1131,
#    '+',
#    '',
#    'gene',
#    'dnaJ',
#    '14167',
#    '15298',
#    '14167',
#    '15298']},
#  {'xStart': 15444,
#   'xEnd': 16557,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 1113,
#   'uid': 'A4PMV1MSQwiQzk0UNz54Zw',
#   'fields': ['chrom',
#    15444,
#    16557,
#    'insL-1',
#    1113,
#    '+',
#    '',
#    'gene',
#    'insL-1',
#    '15444',
#    '16557',
#    '15444',
#    '16557']},
#  {'xStart': 16750,
#   'xEnd': 16960,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 210,
#   'uid': 'efZsZMdZQG6q2UKHfc0Lrg',
#   'fields': ['chrom',
#    16750,
#    16960,
#    'mokC',
#    210,
#    '-',
#    '',
#    'gene',
#    'mokC',
#    '16750',
#    '16960',
#    '16750',
#    '16960']},
#  {'xStart': 16750,
#   'xEnd': 16903,
#   'strand': '-',
#   'chrOffset': 0,
#   'importance': 153,
#   'uid': 'WELScgPDRtWgIETVaewvyQ',
#   'fields': ['chrom',
#    16750,
#    16903,
#    'hokC',
#    153,
#    '-',
#    '',
#    'gene',
#    'hokC',
#    '16750',
#    '16903',
#    '16750',
#    '16903']},
#  {'xStart': 16951,
#   'xEnd': 17006,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 55,
#   'uid': 'ZUxCrxcAT5WKBQCzskhRUw',
#   'fields': ['chrom',
#    16951,
#    17006,
#    'sokC',
#    55,
#    '+',
#    '',
#    'gene',
#    'sokC',
#    '16951',
#    '17006',
#    '16951',
#    '17006']},
#  {'xStart': 17488,
#   'xEnd': 18655,
#   'strand': '+',
#   'chrOffset': 0,
#   'importance': 1167,
#   'uid': 'MO2kE-KVS8eYL42LvBVFbA',
#   'fields': ['chrom',
#    17488,
#    18655,
#    'nhaA',
#    1167,
#    '+',
#    '',
#    'gene',
#    'nhaA',
#    '17488',
#    '18655',
#    '17488',
#    '18655']},
#  {'xStart': ExactPosition(189),
#   'xEnd': ExactPosition(1557056),
#   'type': 'filler',
#   'uid': 'QIZWS9gvQEuO_aFcbPSeuA',
#   'fields': [],
#   'strand': '+'},
#  {'xStart': ExactPosition(1579544),
#   'xEnd': ExactPosition(1579667),
#   'type': 'filler',
#   'uid': 'KLetH6lASuqdZepVtVcABA',
#   'fields': [],
#   'strand': '+'},
#  {'xStart': ExactPosition(1601489),
#   'xEnd': ExactPosition(2097225),
#   'type': 'filler',
#   'uid': 'N3vmiFKQTfqMjPmV85JfKQ',
#   'fields': [],
#   'strand': '+'},
#  {'xStart': ExactPosition(2137901),
#   'xEnd': ExactPosition(3898609),
#   'type': 'filler',
#   'uid': 'DcTeHTukS_uqN6oE2pYdaQ',
#   'fields': [],
#   'strand': '+'},
#  {'xStart': ExactPosition(3927154),
#   'xEnd': ExactPosition(4641628),
#   'type': 'filler',
#   'uid': 'QGYI7yqORWmsUByNCftWzQ',
#   'fields': [],
#   'strand': '+'},
#  {'xStart': ExactPosition(5682),
#   'xEnd': ExactPosition(85511),
#   'type': 'filler',
#   'uid': 'ZZteE7zCQTSKwN28m6sMUw',
#   'fields': [],
#   'strand': '-'},
#  {'xStart': ExactPosition(111648),
#   'xEnd': ExactPosition(189506),
#   'type': 'filler',
#   'uid': 'C7F7x_nKT4S1FZ0uH4REuQ',
#   'fields': [],
#   'strand': '-'},
#  {'xStart': ExactPosition(213677),
#   'xEnd': ExactPosition(4394067),
#   'type': 'filler',
#   'uid': 'KxySUC1OQuKClYpf1IeXMw',
#   'fields': [],
#   'strand': '-'},
#  {'xStart': ExactPosition(4416016),
#   'xEnd': ExactPosition(4640306),
#   'type': 'filler',
#   'uid': 'NCyptZ2uRKake4rpdLH5nw',
#   'fields': [],
#   'strand': '-'}]

# %%
def tiles_wrapper(tile_ids, tile_func):
    tile_values = []

    for tile_id in tile_ids:
        parts = tile_id.split('.')

        if len(parts) < 3:
            raise IndexError("Not enough tile info present")

        z = int(parts[1])
        x = int(parts[2])

        ret_array = tile_func(z, x)

        tile_values += [(tile_id, ret_array)]

    return tile_values

# %%
#tiles_wrapper(['x.0.0'], lambda z,x: tiles(gbrec, tsinfo, z, x))

# %%
from higlass.tilesets import Tileset

def gbk(gbrec):
    """1d labels"""
    return Tileset(
        uuid='hi',
        tileset_info=lambda: tileset_info(gbrec),
        tiles=lambda tids: tiles_wrapper(tids, lambda z,x: tiles(gbrec, tsinfo, z, x))
    )

# %%
ts = gbk(gbrec)

# %%
import higlass
from higlass.client import View, Track

(display, server, viewconf) = higlass.display([
    View([
        Track('top-axis'),
        Track(
            track_type='horizontal-gene-annotations',
            position='top',
            tileset=ts,
            height=100)
    ])
], server_port=8112)

display
# Out:
# HiGlassDisplay(viewconf={'editable': True, 'views': [{'uid': 'b-BE01_xSBON1YitSsaj3A', 'tracks': {'top': [{'ty…

# %%
server

# %%
server.port
# Out:
# 64406
